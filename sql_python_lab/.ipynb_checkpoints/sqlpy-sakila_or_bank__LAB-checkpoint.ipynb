# %% [markdown]
# # Lets df and viz your sql data

# %%
# Import numpy, pandas and pymysql sqlalchemy (following what you have learned in previous lessons):
import pymysql 
from sqlalchemy import create_engine 
import pandas as pd 
import getpass # to get the password without it being visible 
password= getpass.getpass()
# Out:
# ········

# %% [markdown]
# # Challenge 1 - Load and Evaluate the Datasets
#
# #### In this challenge we will load data from MySQL Sakila database or MySQL bank database (or any other DB); by querying and evaluating the results returned using MySQL we can be selective about the data used to make visualisation with seaborn/matplotlib very easy. Ideally you want to bring some data from SQL into python which will allow you to plot a trend or comparison.
#
# In the cell below, create a mysql engine for your local mysql instance and include your username, password and database schema name by creating a variable connection string following the following pattern:
#
# create_engine(‘dialect+driver://username:password@host:port/database’)
#
# This is the format to create the connection string and engine for a local mysql connection
#
# > connection_string = 'mysql+pymysql://root:' + 'password' + '@localhost/DB'
#
# - replace root with your username and password with your password
# - replace DB with database name
#
# > engine = create_engine(connection_string)

# %%
# Your code here:

connection_string = 'mysql+pymysql://root:' + password + '@localhost/bank'
engine= create_engine(connection_string)

# %% [markdown]
# Use this connection to load data with a sql query which connects the target tables in your database using joins, selects the fields you wish to work with and any aggregation columns + grouping / window function new columns or filters by where/having as appropriate. You can draw on any of the labs or lessons to establish what your query should look like. Its ok if this stage is a little trial and error but I recommend testing the query in your MySql client to ensure it returns the results you want!

# %%
dloans=pd.read_sql_query('''
select 
d.A2 as districtname, d.A3 as region,
sum(l.amount) as totalborrrowed, 
count(l.loan_id) as noofloanstaken,
round(avg(l.amount)) as avgloanvalue,
round(avg(d.A11)) as avg_salary
from loan l
join account a using(account_id)
join district d on 
a.district_id= d.A1
group by d.A2, d.A3
order by sum(l.amount) desc
limit 1000
''',engine)

# %% [markdown]
# once you have your sql query worked out, make sure you turn your query response into a pandas dataframe in the format
#
# > df = pd.read_sql_query(query, engine)

# %%
# Your code here:

dloans
# Out:
#          districtname         region  totalborrrowed  noofloanstaken  \
# 0         Hl.m. Praha         Prague      12932412.0              84
# 1        Brno - mesto  south Moravia       4049400.0              24
# 2     Ostrava - mesto  north Moravia       3260220.0              20
# 3             Karvina  north Moravia       3059820.0              24
# 4                Zlin  south Moravia       3012768.0              17
# ..                ...            ...             ...             ...
# 72     Usti nad Labem  north Bohemia        347484.0               3
# 73             Semily   east Bohemia        276180.0               3
# 74            Klatovy   west Bohemia        270876.0               3
# 75            Sokolov   west Bohemia        148524.0               2
# 76  Jablonec n. Nisou  north Bohemia        127200.0               1
#
#     avgloanvalue  avg_salary
# 0       153957.0     12541.0
# 1       168725.0      9897.0
# 2       163011.0     10673.0
# 3       127493.0     10177.0
# 4       177222.0      9624.0
# ..           ...         ...
# 72      115828.0      9832.0
# 73       92060.0      8208.0
# 74       90292.0      8554.0
# 75       74262.0      9650.0
# 76      127200.0      8867.0
#
# [77 rows x 6 columns]

# %% [markdown]
# #### Let's start examining the dataset to ensure we have the data we want to visualise.
#
# First look at the first five rows using the `head` function.

# %%
# Your code here:

dloans.head(5)
# Out:
#       districtname         region  totalborrrowed  noofloanstaken  \
# 0      Hl.m. Praha         Prague      12932412.0              84
# 1     Brno - mesto  south Moravia       4049400.0              24
# 2  Ostrava - mesto  north Moravia       3260220.0              20
# 3          Karvina  north Moravia       3059820.0              24
# 4             Zlin  south Moravia       3012768.0              17
#
#    avgloanvalue  avg_salary
# 0      153957.0     12541.0
# 1      168725.0      9897.0
# 2      163011.0     10673.0
# 3      127493.0     10177.0
# 4      177222.0      9624.0

# %% [markdown]
# Next, lets use the `info` function to see the dtypes and row counts

# %%
# Your code here:
dloans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   districtname    77 non-null     object
#  1   region          77 non-null     object
#  2   totalborrrowed  77 non-null     float64
#  3   noofloanstaken  77 non-null     int64
#  4   avgloanvalue    77 non-null     float64
#  5   avg_salary      77 non-null     float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 3.7+ KB

# %% [markdown]
# Next, we'll examine the `describe` function to see the descriptive statistics for the numeric variables.

# %%
# Your code here:
dloans.describe()
# Out:
#        totalborrrowed  noofloanstaken   avgloanvalue    avg_salary
# count    7.700000e+01       77.000000      77.000000     77.000000
# mean     1.341062e+06        8.857143  148347.116883   9031.675325
# std      1.528991e+06        9.686825   43582.971246    790.202347
# min      1.272000e+05        1.000000   74262.000000   8110.000000
# 25%      6.943680e+05        6.000000  118466.000000   8512.000000
# 50%      1.076580e+06        7.000000  145458.000000   8814.000000
# 75%      1.460796e+06        9.000000  170458.000000   9317.000000
# max      1.293241e+07       84.000000  294730.000000  12541.000000

# %% [markdown]
# #### At this stage it may be necessary to load another set of data with an additional mysql query and repeat the stages above - perhaps you are thinking to join the results of your two queries together or you think that both should be visualised separately to answer the question you came up with?
#
# Do this in the following 3 cells below.

# %%
bad_good_loans=pd.read_sql_query('''select a.account_id, l.loan_id, l.amount-l.payments as balance,
case 
when status='A' then 'good-loan repaid'
when status='B' then 'defaulter-contract finished'
when status ='C' then 'good - on track'
else 'in debt- contract running'
end 
as 'status_description'
from loan l
join account a
using (account_id)
order by status_description, balance DESC''',engine)

# %%
# Your code here:
bad_good_loans.head(50)
# Out:
#     account_id  loan_id   balance           status_description
# 0         6034     6228  456778.0  defaulter-contract finished
# 1         2176     5395  290780.0  defaulter-contract finished
# 2         6051     6232  268975.0  defaulter-contract finished
# 3         6118     6244  263130.0  defaulter-contract finished
# 4         8566     6738  223825.0  defaulter-contract finished
# 5        10131     7066  209405.0  defaulter-contract finished
# 6          790     5126  203792.0  defaulter-contract finished
# 7         1106     5176  184529.0  defaulter-contract finished
# 8         7824     6594  181792.0  defaulter-contract finished
# 9          347     5045  179423.0  defaulter-contract finished
# 10        5442     6112  167463.0  defaulter-contract finished
# 11        5428     6111  167463.0  defaulter-contract finished
# 12       11021     7241  161943.0  defaulter-contract finished
# 13        1527     5269  159495.0  defaulter-contract finished
# 14        4081     5805  132158.0  defaulter-contract finished
# 15        1787     5314   88363.0  defaulter-contract finished
# 16        3273     5643   86636.0  defaulter-contract finished
# 17        5927     6210   85399.0  defaulter-contract finished
# 18       10266     7097   72473.0  defaulter-contract finished
# 19        6473     6316   70499.0  defaulter-contract finished
# 20        6400     6303   69391.0  defaulter-contract finished
# 21        4462     5892   63710.0  defaulter-contract finished
# 22        1993     5352   62700.0  defaulter-contract finished
# 23        5066     6027   59087.0  defaulter-contract finished
# 24        6609     6342   58485.0  defaulter-contract finished
# 25        1888     5338   52580.0  defaulter-contract finished
# 26        4320     5856   47080.0  defaulter-contract finished
# 27        8073     6650   45210.0  defaulter-contract finished
# 28        7418     6501   27753.0  defaulter-contract finished
# 29          19     4961   27753.0  defaulter-contract finished
# 30        9199     6865   26994.0  defaulter-contract finished
# 31        7542     6534  580973.0              good - on track
# 32        8926     6791  557196.0              good - on track
# 33         817     5132  529525.0              good - on track
# 34        2936     5569  495600.0              good - on track
# 35        7049     6436  486927.0              good - on track
# 36        6950     6415  465770.0              good - on track
# 37         339     5043  460259.0              good - on track
# 38        2516     5486  456887.0              good - on track
# 39        4774     5970  455383.0              good - on track
# 40        3679     5725  435596.0              good - on track
# 41        2910     5561  430169.0              good - on track
# 42        2545     5491  419851.0              good - on track
# 43       11349     7304  412882.0              good - on track
# 44       10297     7101  412237.0              good - on track
# 45       10520     7154  410640.0              good - on track
# 46        8377     6704  410109.0              good - on track
# 47        2246     5419  408870.0              good - on track
# 48        4190     5830  399017.0              good - on track
# 49        4650     5938  395300.0              good - on track

# %%
# Your code here:
bad_good_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   account_id          682 non-null    int64
#  1   loan_id             682 non-null    int64
#  2   balance             682 non-null    float64
#  3   status_description  682 non-null    object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 21.4+ KB

# %%
bad_good_loans.describe()
# Out:
#          account_id      loan_id        balance
# count    682.000000   682.000000     682.000000
# mean    5824.162757  6172.466276  147219.511730
# std     3283.512681   682.579279  111856.147524
# min        2.000000  4959.000000    4565.000000
# 25%     2967.000000  5577.500000   62852.250000
# 50%     5738.500000  6176.500000  113438.000000
# 75%     8686.000000  6752.500000  205723.250000
# max    11362.000000  7308.000000  580973.000000

# %% [markdown]
# #### Exploratory Data Analysis
# You might benefit from doing some elementary EDA at this stage before jumping into plotting data, as this can help you grasp the shape, diversity and gaps in the data you have selected. This is a timesaver!
#
# For this task you can use matplotlib/seaborn so you will need to import them, then work with :
#
# - df.hist()
# - sns.boxplot(x=df["colname"])

# %%
# Your code here (import visual libraries)

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Your code here (histogram all numericals)

plotdata= dloans
plotdata.plot(kind="bar",figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
plotdata= bad_good_loans
plotdata.plot(kind="bar",figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
# Your code here (box plot to see outliers for specific columns)
sns.boxplot(x=dloans['totalborrrowed'])
# Out:
# <AxesSubplot:xlabel='totalborrrowed'>

# %%
q_hi  = dloans["totalborrrowed"].quantile(0.99)

dloansfiltered = dloans[(dloans["totalborrrowed"] < q_hi)]

# %% [markdown]
# ### Optional - if you are using more than one sql query
#
# If you decided to load two dataframes from two separate mysql queries and need to merge them using the merge concat or join functions, do so now. You can follow [this tutorial](https://realpython.com/pandas-merge-join-and-concat/) for more information about bringing dataframes together

# %%
# your code here 

#joindata = dloans.join(
    bad_good_loans.set_index(["account_id", "DATE"]),
    
#can't make it, no time!

# %% [markdown]
# # Challenge 2 - Export your data frame as a csv
#
# Export df to a csv file using the `df.to_csv` function, filtered if suitable, excluding any columns which are not useful for further analysis

# %%
# Your code here:

dloansfiltered.to_csv('dloans', index=False)

# %%
bad_good_loans.to_csv('good_bad_loans', index=False)

# %% [markdown]
# # Challenge 3: Visualise relationships or trends found in the data
#
# At this stage you can visualise the data in your chosen tool, Tableau, Excel, Python(matploitlib,seaborn)
#
# **Business Question**: think about what are the question(s) you want to answer with the data you have gathered from the MySQL database. Make the question as specific as possible
# - for example, are childrens films rented more frequently on weekends than comedies?
#
# **Visuals**: Think about what plot type best supports answering your question(s). Each plot/ visualisation should have an appropriate title, legend and axis labels, so the meaning is as clear as possible without needing a caption. Make use of colour pallettes ! dont just create a blue plot :)

# %%
# (if plotting in python) Your code here:
# Out:
# <AxesSubplot:xlabel='totalborrrowed'>

# %%
x1 = dloansfiltered.plot.scatter(x='totalborrrowed',
                      y='avg_salary',
                      c='avgloanvalue',
                                colormap='viridis')

# %%
#There seems to be is no connection between the average salary and the value of the loans
